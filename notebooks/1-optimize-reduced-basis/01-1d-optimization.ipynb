# %%
from skreducedmodel.reducedbasis import ReducedBasis, error, normalize_set
from optuna.samplers import TPESampler
import matplotlib.pyplot as plt
import numpy as np
import optuna

# %% [markdown]
# # Load Data

# %%
# physical points
times = np.linspace(-2750, 100, 28501)

# training set
filepath_train = "../../data/1d/1d_200_q_1_to_8.npy"
train = np.load(filepath_train)  
parameters_train = np.linspace(1, 8, train.shape[0])

# validation set
filepath_valid = "../../data/1d/1d_300_q_1_to_8.npy"
valid = np.load(filepath_valid)
valid_normalized = normalize_set(valid, times)
parameters_valid = np.linspace(1, 8, valid.shape[0])

# test set
filepath_test = "../../data/1d/1d_400_q_1_to_8.npy"
test = np.load(filepath_test)
test_normalized = normalize_set(test, times)
parameters_test = np.linspace(1, 8, test.shape[0])

# %% [markdown]
# # Optimize

# %%
def objective(trial):
    lmax = trial.suggest_int("lmax", 0, 5)
    nmax = trial.suggest_int("nmax", 5, 15)
    seed = trial.suggest_int("seed", 0, train.shape[0]-1)
        
    # build a reduced basis
    rb = ReducedBasis(index_seed_global_rb=seed, lmax=lmax, nmax=nmax)
    rb.fit(train, parameters_train, times)
    
    projections = []
    for h_t, q_t in zip(valid, parameters_valid):
        projections.append(rb.transform(h_t, q_t))
    projections = np.asarray(projections)
    errors = []

    for h_proy, h_valid in zip(projections, valid):
        errors.append(error(h_proy, h_valid, times))
    return max(errors)

# %%
# If the optimization is already done, don't do it again
try:
    study = optuna.create_study(study_name=f"1dTPEmv-ts{train.shape[0]}-vs{valid.shape[0]}",
                                storage="sqlite:///studies.db", 
                                load_if_exists=False, 
                                sampler=TPESampler(multivariate=True, seed=12))
except:
    study = optuna.load_study(study_name="1dTPEmv-ts200-vs300",
                                storage="sqlite:///studies.db")
else:
    study.optimize(objective, n_trials=100, gc_after_trial=True)
# Out:
# c:\Users\eliaz\AppData\Local\Programs\Python\Python311\Lib\site-packages\optuna\samplers\_tpe\sampler.py:282: ExperimentalWarning: ``multivariate`` option is an experimental feature. The interface can change in the future.
#   warnings.warn(
# [I 2023-05-15 21:06:12,202] A new study created in RDB with name: 1dTPEmv-ts200-vs300
# [I 2023-05-15 21:06:16,901] Trial 0 finished with value: 3.1381025680297564e-13 and parameters: {'lmax': 2, 'nmax': 15, 'seed': 146}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:20,001] Trial 1 finished with value: 6.8083545286855545 and parameters: {'lmax': 3, 'nmax': 6, 'seed': 31}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:22,284] Trial 2 finished with value: 0.0418768219131432 and parameters: {'lmax': 0, 'nmax': 14, 'seed': 120}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:25,010] Trial 3 finished with value: 2.8306790464984966 and parameters: {'lmax': 4, 'nmax': 5, 'seed': 193}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:28,481] Trial 4 finished with value: 5.5914602234764255 and parameters: {'lmax': 4, 'nmax': 7, 'seed': 36}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:30,577] Trial 5 finished with value: 4.837400954151955 and parameters: {'lmax': 1, 'nmax': 8, 'seed': 104}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:33,279] Trial 6 finished with value: 0.09051592627886099 and parameters: {'lmax': 2, 'nmax': 8, 'seed': 122}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:34,649] Trial 7 finished with value: 7.361107860685962 and parameters: {'lmax': 0, 'nmax': 8, 'seed': 73}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:39,961] Trial 8 finished with value: 0.001887918571397342 and parameters: {'lmax': 2, 'nmax': 13, 'seed': 39}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:44,039] Trial 9 finished with value: 0.26692587263771056 and parameters: {'lmax': 3, 'nmax': 11, 'seed': 9}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:48,333] Trial 10 finished with value: 3.1381025680297564e-13 and parameters: {'lmax': 3, 'nmax': 15, 'seed': 165}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:52,611] Trial 11 finished with value: 9.412826843892772e-13 and parameters: {'lmax': 3, 'nmax': 15, 'seed': 153}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:06:56,000] Trial 12 finished with value: 5.890389448842679e-10 and parameters: {'lmax': 1, 'nmax': 15, 'seed': 185}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:00,386] Trial 13 finished with value: 3.1381025680297564e-13 and parameters: {'lmax': 5, 'nmax': 14, 'seed': 163}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:03,645] Trial 14 finished with value: 0.00019282293585528762 and parameters: {'lmax': 2, 'nmax': 10, 'seed': 195}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:07,594] Trial 15 finished with value: 1.1105886901529823e-08 and parameters: {'lmax': 2, 'nmax': 13, 'seed': 120}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:12,489] Trial 16 finished with value: 5.230607333944843e-12 and parameters: {'lmax': 4, 'nmax': 13, 'seed': 107}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:16,504] Trial 17 finished with value: 2.6231371585023236e-09 and parameters: {'lmax': 3, 'nmax': 12, 'seed': 188}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:20,919] Trial 18 finished with value: 4.943042628123692e-05 and parameters: {'lmax': 5, 'nmax': 9, 'seed': 91}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:25,734] Trial 19 finished with value: 8.135299202173346e-11 and parameters: {'lmax': 2, 'nmax': 15, 'seed': 110}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:30,783] Trial 20 finished with value: 5.181564782737366e-13 and parameters: {'lmax': 4, 'nmax': 15, 'seed': 186}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:35,101] Trial 21 finished with value: 9.412826843892772e-13 and parameters: {'lmax': 5, 'nmax': 14, 'seed': 154}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:39,680] Trial 22 finished with value: 3.61254392249406e-13 and parameters: {'lmax': 5, 'nmax': 12, 'seed': 165}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:43,966] Trial 23 finished with value: 9.639202512784657e-13 and parameters: {'lmax': 5, 'nmax': 15, 'seed': 126}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:47,978] Trial 24 finished with value: 2.3570795344898142e-11 and parameters: {'lmax': 2, 'nmax': 15, 'seed': 192}. Best is trial 0 with value: 3.1381025680297564e-13.
# [I 2023-05-15 21:07:52,334] Trial 25 finished with value: 8.409699761266026e-08 and parameters: {'lmax': 5, 'nmax': 9, 'seed': 190}. Best is trial 0 with value: 3.1381025680297564e-13.

# %% [markdown]
# # Best hyperparameters Found

# %%
best_params = study.best_params; 
for param, value in best_params.items():
    print(f"Best {param} = {value}") 
    # the best seed is an index
print(f"Best Validation Error {study.best_value:.3e}")
# Out:
# Best lmax = 0
# Best nmax = 20
# Best seed = 141
# Best Validation Error 1.532e-08

# %% [markdown]
# ### Test Error

# %%
test_rb = ReducedBasis(index_seed_global_rb=best_params["seed"], 
                       lmax=best_params["lmax"], 
                       nmax=best_params["nmax"])
test_rb.fit(train, parameters_train, times)
projection_test = test_rb.transform(test, parameters_test)
test_errors = error(projection_test, test, times)

# %%
plt.figure(figsize=(6,2))
plt.plot(parameters_test, test_errors)
plt.yscale("log")

plt.xlabel("q")

for leaf in test_rb.tree.leaves:
    for p in leaf.indices:
        plt.axvline(parameters_train[p],lw=.5)

# %% [markdown]
# # Visualize Optimization Results

# %% [markdown]
# ### Hyperparameter Importances

# %%
optuna.visualization.plot_param_importances(study)

# %%
# dataframe with trials
db = study.trials_dataframe()

# %%
# seed
from matplotlib import colors

x = parameters_train[db.params_seed]
y = db.value

norm = colors.LogNorm(min(db.value), max(db.value))
plt.figure(figsize=(10, 8))
plt.scatter(x, y, c= db.value, edgecolors="gray",norm=norm)
plt.grid()
plt.colorbar(label="Validation Error")
plt.xlabel(r"seed $q_0$")
plt.ylabel(r"Validation Error")
plt.yscale("log")

# %%
# seed
from matplotlib import colors

x = db.params_lmax
y = db.value

norm = colors.LogNorm(min(db.value), max(db.value))
plt.figure(figsize=(10, 8))
plt.scatter(x, y, c= db.value, edgecolors="gray",norm=norm)
plt.grid()
plt.colorbar(label="Validation Error")
plt.xlabel(r"$l_{max}$")
plt.ylabel(r"Validation Error")
plt.yscale("log")

# %%
# seed
from matplotlib import colors

x = db.params_nmax
y = db.value

norm = colors.LogNorm(min(db.value), max(db.value))
plt.figure(figsize=(10, 8))
plt.scatter(x, y, c= db.value, edgecolors="gray",norm=norm)
plt.grid()
plt.colorbar(label="Validation Error")
plt.xlabel(r"$n_{max}$")
plt.ylabel(r"Validation Error")
plt.yscale("log")

# %% [markdown]
# ### Evolution of Validation Error

# %%
from matplotlib import colors

x = db.number
y = db.value

min_errs = [y[0]]
min_errs_it = [x[0]]
for i, err in enumerate(y):
    if err <= min(min_errs):
        min_errs.append(err)
        min_errs_it.append(x[i])

norm = colors.LogNorm(y.min(), y.max())
plt.figure(figsize=(10, 8))
plt.scatter(x, y, c=y, edgecolors="gray",norm=norm)
plt.plot(min_errs_it, min_errs, "r--", label="Best Validation Error Found")
plt.grid()
plt.colorbar(label="Validation Error")
plt.yscale("log")
plt.xlabel("Iteration")
plt.ylabel("Validation Error")
plt.legend()

# %% [markdown]
# ### Evolution of Hyperparameters

# %%
# lmax
x = db.number
y = db.params_lmax

norm = colors.LogNorm(min(db.value), max(db.value))
plt.figure(figsize=(10, 8))
plt.scatter(x, y, c= db.value, edgecolors="gray",norm=norm)
plt.grid()
plt.colorbar()
plt.xlabel("iteración")
plt.ylabel(r"$l_{max}$")
# Out:
# Text(0, 0.5, '$l_{max}$')

# %%
# n max
x = db.number
y = db.params_nmax

norm = colors.LogNorm(min(db.value), max(db.value))
plt.figure(figsize=(10, 8))
plt.scatter(x, y, c= db.value, edgecolors="gray",norm=norm)
plt.grid()
plt.colorbar()
plt.xlabel("Iteration")
plt.ylabel(r"$n_{max}$")
# Out:
# Text(0, 0.5, '$n_{max}$')

# %%
# seed q0
x = db.number
y = parameters_train[db.params_seed]

norm = colors.LogNorm(min(db.value), max(db.value))
plt.figure(figsize=(10, 8))
plt.scatter(x, y, c= db.value, edgecolors="gray",norm=norm)
plt.grid()
plt.colorbar()
plt.xlabel("Iteration")
plt.ylabel(r"seed $q_0$")
# Out:
# Text(0, 0.5, 'seed $q_0$')
